# %%
import matplotlib.pyplot as plt # for plotting
from tmaze_toolkit.data.extraction import selectDoorCoords, extractDoorTraces, initial_coords
from tmaze_toolkit.processing.signal import bandpass_filter, process_door_traces
from tmaze_toolkit.visualization.plotDoorTraces import plotDoorTraces
from tmaze_toolkit.data.openFunctions import openDoorTracesPkl
from tmaze_toolkit.processing.extractTrialTimes import extract_floor_traces, extract_trial_times, verify_correct_trial_times
from tmaze_toolkit.data.jsonProcessing import load_json_files, add_trajectories, save_outDict
from tmaze_toolkit.visualization.plotTrajectory import plot_trajectory
from tmaze_toolkit.processing.normalize import normalize_trajectory
from tmaze_toolkit.data.deeplabcutProcessing import load_deeplabcut_files

# %%
# Specificy Door Traces .pkl file
# This file contains the door traces for the video
pkl_file = r"N:\TMAZE\MasterMouseFolder\ATO1\Clipped Videos\ATO1_2025-03-23T14_49_36_doorTraces.pkl"

# Open this pkl and load the door traces
data = openDoorTracesPkl(pkl_file)

# specify location of the dlc model and traces
dlcFile = r"N:\TMAZE\MasterMouseFolder\ATO1\Clipped Videos\ATO1_2025-03-23T14_49_36DLC_resnet50_Intermidiate textured DLC model Sep10shuffle1_100000.h5"
# specify location of the json files that contain maze metadata 
jsonFiles = r"N:\TMAZE\MasterMouseFolder\ATO1\jsonData\data_ATO1_20250323*"

# Open the json files and load the metadata
metaData = load_json_files(jsonFiles)

# If normalizing the trajectory, specify the video file location
videoFile = r"N:\TMAZE\MasterMouseFolder\ATO1\Clipped Videos\ATO1_2025-03-23T14_49_36.mp4"
# Out:
# Found 1 json files
# Animal ID: ATO1
# Working on file N:\TMAZE\MasterMouseFolder\ATO1\jsonData\data_ATO1_20250323_144928.json

# %%
# check that the extracted door traces are reliable
plotDoorTraces(data)

# %%
# Process the door traces
data = process_door_traces(data)

# Visualize result of processed data
plotDoorTraces(data)

# %%
# Extract Trial Start and End Times from the door Traces
events = extract_trial_times(data)
# Out:
# Floor Starts: 57
# Floor Ends: 57
# Trial Starts: 43
# Trial Ends: 43
# Trial 0 likely has a missed detection in the doors 1 and 2
# Trial 1 likely has a missed detection in the doors 1 and 2
# Trial 2 likely has a missed detection in the doors 1 and 2
# Trial 3 likely has a missed detection in the doors 1 and 2
# Trial 4 likely has a missed detection in the doors 1 and 2
# Trial 5 likely has a missed detection in the doors 1 and 2
# Trial 6 likely has a missed detection in the doors 1 and 2
# Trial 7 likely has a missed detection in the doors 1 and 2
# Trial 8 likely has a missed detection in the doors 1 and 2
# Trial 9 likely has a missed detection in the doors 1 and 2
# Trial 10 likely has a missed detection in the doors 1 and 2
# Trial 11 likely has a missed detection in the doors 1 and 2
# Trial 12 likely has a missed detection in the doors 1 and 2
# Trial 13 likely has a missed detection in the doors 1 and 2
# Trial 14 likely has a missed detection in the doors 1 and 2
# Trial 15 likely has a missed detection in the doors 1 and 2
# Trial 16 likely has a missed detection in the doors 1 and 2
# Trial 17 likely has a missed detection in the doors 1 and 2
# Trial 18 likely has a missed detection in the doors 1 and 2
# Trial 19 likely has a missed detection in the doors 1 and 2
# Trial 20 likely has a missed detection in the doors 1 and 2
# Trial 21 likely has a missed detection in the doors 1 and 2
# Trial 22 likely has a missed detection in the doors 1 and 2
# Trial 23 likely has a missed detection in the doors 1 and 2
# Trial 24 likely has a missed detection in the doors 1 and 2
# Trial 25 likely has a missed detection in the doors 1 and 2
# Trial 26 likely has a missed detection in the doors 1 and 2
# Trial 27 likely has a missed detection in the doors 1 and 2
# Trial 28 likely has a missed detection in the doors 1 and 2
# Trial 29 likely has a missed detection in the doors 1 and 2
# Trial 30 likely has a missed detection in the doors 1 and 2
# Trial 31 likely has a missed detection in the doors 1 and 2
# Trial 32 likely has a missed detection in the doors 1 and 2
# Trial 33 likely has a missed detection in the doors 1 and 2
# Trial 34 likely has a missed detection in the doors 1 and 2
# Trial 35 likely has a missed detection in the doors 1 and 2
# Trial 36 likely has a missed detection in the doors 1 and 2
# Trial 37 likely has a missed detection in the doors 1 and 2
# Trial 38 likely has a missed detection in the doors 1 and 2
# Trial 39 likely has a missed detection in the doors 1 and 2
# Trial 40 likely has a missed detection in the doors 1 and 2
# Trial 41 likely has a missed detection in the doors 1 and 2
# Trial 42 likely has a missed detection in the doors 1 and 2

# %%
# Verify that the number of detected trials matches the information in the json files
verify_correct_trial_times(events, jsonFiles)
# Out:
# Found 1 json files
# Animal ID: ATO1
# Working on file N:\TMAZE\MasterMouseFolder\ATO1\jsonData\data_ATO1_20250323_144928.json
# Warning: Number of trials in the json file and the trial dataframe do not match
# False

# %%
# visualize metadata dictionary
print(metaData[43])
# Out:
# {'MazeTexture': 'CNO', 'rewardBefLick': False, 'lickUntilCorrect': False, 'decision': 'correct', 'floorID': 'F,4', 'time_for_trial': 1, 'valve': 4, 'lick': 'right(V2)', 'trial_number': 44, 'trial_time': [2025, 3, 23, 15, 39, 41, 6, 82, 1], 'right_probability': 0.5, 'rewardAmount(ms)': 5, 'BiasCorrection(T/F)': False, 'coneHeight_1(floor1)': '0.5', 'coneHeight_2(floor2)': '1', 'Injection': '2'}

# %%
# Load DLC dictionary from the H5 file
import Pandas as pd

dlcFile = r"N:\TMAZE\MasterMouseFolder\ATO1\pkl and H5 files\ATO1_2025-03-24T15_23_27DLC_resnet50_Intermidiate textured DLC model Sep10shuffle1_100000.h5"
with h5py.File(dlcFile, 'r') as f:
    # Check the keys in the HDF5 file
    print("Keys in the HDF5 file:")
    for key in f.keys():
        print(key)

dlc_dict = pd.read_hdf(dlcFile, key='df_with_missing')


# Match the mouse movements to the trials using time stamps from events
metaData = add_trajectories(metaData, dlc_dict, events)

# Specify location to save the metadata + trajectories
# This will be a json file that contains the metadata and the trajectories
savePath = r"N:\TMAZE\MasterMouseFolder\ATO6\jsonData\data_ATO6_20250322.json"

# Save the updated metadata dictionary to a json file
save_outDict(metaData, savePath)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tables
#   Using cached tables-3.9.2-cp39-cp39-win_amd64.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\letmedoit\appdata\roaming\python\python39\site-packages (from tables) (2.0.2)
# Collecting numexpr>=2.6.2 (from tables)
#   Using cached numexpr-2.10.2-cp39-cp39-win_amd64.whl.metadata (8.3 kB)
# Requirement already satisfied: packaging in c:\users\letmedoit\appdata\roaming\python\python39\site-packages (from tables) (24.2)
# Collecting py-cpuinfo (from tables)
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting blosc2>=2.3.0 (from tables)
#   Using cached blosc2-2.5.1-cp39-cp39-win_amd64.whl.metadata (9.4 kB)
# Collecting ndindex>=1.4 (from blosc2>=2.3.0->tables)
#   Downloading ndindex-1.9.2-cp39-cp39-win_amd64.whl.metadata (3.5 kB)
# Collecting msgpack (from blosc2>=2.3.0->tables)
#   Using cached msgpack-1.1.0-cp39-cp39-win_amd64.whl.metadata (8.6 kB)
# Using cached tables-3.9.2-cp39-cp39-win_amd64.whl (4.4 MB)
# Using cached blosc2-2.5.1-cp39-cp39-win_amd64.whl (2.3 MB)
# Using cached numexpr-2.10.2-cp39-cp39-win_amd64.whl (144 kB)
# Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Downloading ndindex-1.9.2-cp39-cp39-win_amd64.whl (160 kB)
# Using cached msgpack-1.1.0-cp39-cp39-win_amd64.whl (74 kB)
# Installing collected packages: py-cpuinfo, numexpr, ndindex, msgpack, blosc2, tables
# Successfully installed blosc2-2.5.1 msgpack-1.1.0 ndindex-1.9.2 numexpr-2.10.2 py-cpuinfo-9.0.0 tables-3.9.2
# Keys in the HDF5 file:
# df_with_missing
#   WARNING: The script cpuinfo.exe is installed in 'C:\Users\letmedoit\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts pt2to3.exe, ptdump.exe, ptrepack.exe and pttree.exe are installed in 'C:\Users\letmedoit\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 16
#      13     for key in f.keys():
#      14         print(key)
# ---> 16 dlc_dict = pd.read_hdf(dlcFile, key='df_with_missing')
#      19 # Match the mouse movements to the trials using time stamps from events
#      20 metaData = add_trajectories(metaData, dlc_dict, events)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\pytables.py:426, in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     423 if not exists:
#     424     raise FileNotFoundError(f"File {path_or_buf} does not exist")
# --> 426 store = HDFStore(path_or_buf, mode=mode, errors=errors, **kwargs)
#     427 # can't auto open/close if we are using an iterator
#     428 # so delegate to the iterator
#     429 auto_close = True
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\pytables.py:566, in HDFStore.__init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     563 if "format" in kwargs:
#     564     raise ValueError("format is not a defined argument for HDFStore")
# --> 566 tables = import_optional_dependency("tables")
#     568 if complib is not None and complib not in tables.filters.all_complibs:
#     569     raise ValueError(
#     570         f"complib only supports {tables.filters.all_complibs} compression."
#     571     )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     130 msg = (
#     131     f"Missing optional dependency '{install_name}'. {extra} "
#     132     f"Use pip or conda to install {install_name}."
#     133 )
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#     137     if errors == "raise":
#
# File c:\ProgramData\miniconda3\envs\myenv\lib\importlib\__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tables\__init__.py:72
#      68     raise RuntimeError("Blosc2 library not found. "
#      69                        f"I looked for \"{', '.join(blosc2_search_paths)}\"")
#      71 # Necessary imports to get versions stored on the cython extension
# ---> 72 from .utilsextension import get_hdf5_version as _get_hdf5_version
#      74 from ._version import __version__
#      76 hdf5_version = _get_hdf5_version()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tables\utilsextension.pyx:1, in init tables.utilsextension()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
# Normalize the Traces and add to the json file dictionary (metadata)
metaData = normalize_trajectory(metaData, videoFile)

# Specificy save location for the normalized data

savePath = 
# Save the updated metadata dictionary to a json file
save_outDict(metaData, savePath)
# Out:
#   Cell In[17], line 6
#     savePath =
#                ^
# SyntaxError: invalid syntax

# %%
# Example Plotting Traces
plot_trajectory(metaData, videoFile)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Example Plotting Traces
# ----> 2 plot_trajectory(metaData, videoFile)
#
# File c:\users\letmedoit\tmaze-toolkit\tmaze_toolkit\visualization\plotTrajectory.py:17, in plot_trajectory(jsonFile, videoFile, lick, bodyPart, confidence_threshold)
#      15 plt.figure()
#      16 plt.imshow(frame,cmap='gray')
# ---> 17 filt_x = np.copy(outDict[k]['trajectory'].droplevel(0,axis=1)[bodyPart]['x'])
#      18 filt_x[outDict[k]['trajectory'].droplevel(0,axis=1)[bodyPart]['likelihood'] < confidence_threshold] = np.nan
#      19 filt_y = np.copy(outDict[k]['trajectory'].droplevel(0,axis=1)[bodyPart]['y'])
#
# KeyError: 'trajectory'
